# %%
import numpy as np
import pandas as pd
import plotly.express as px

# %%
file = "Atlas_difference_lightcurve.txt"
df = pd.read_csv(
    file,
    delim_whitespace=True,
    comment="#",
    names=[
        "MJD", "m", "dm", "uJy", "duJy", "F", "err", "chi/N",
        "RA", "Dec", "x", "y", "maj", "min", "phi",
        "apfit", "mag5sig", "Sky", "Obs"
    ])
# Out:
# /tmp/ipykernel_5903/3112956363.py:2: FutureWarning:
#
# The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead

# %% [markdown]
# file = "Atlas_difference_lightcurve.txt"
# df = pd.read_csv(
#     file,
#     delim_whitespace=True,
#     comment="#",
#     names=[
#         "MJD", "m", "dm", "uJy", "duJy", "F", "err", "chi/N",
#         "RA", "Dec", "x", "y", "maj", "min", "phi",
#         "apfit", "mag5sig", "Sky", "Obs"
#     ])

# %%
y_param = "m"
orange = df[(df['F'] == 'o') & (df['duJy'] < 10000) & (df['err'] == 0) & (df['x'] > 100) & (df['x'] < 10460) & (df['y'] > 100)
            & (df['y'] < 10460) & (df['maj'] < 5) & (df['maj'] > 1.6) & (df['min'] < 5) & (df['min'] > 1.6) & (df['apfit'] > -1)
            & (df['apfit'] < -0.1) & (df['mag5sig'] > 17) & (df['Sky'] > 17) & (df['m'] > 0) & (df['dm'] < 2)]

cyan = df[(df['F'] == 'c') & (df['duJy'] < 10000) & (df['err'] == 0) & (df['x'] > 100) & (df['x'] < 10460) & (df['y'] > 100)
            & (df['y'] < 10460) & (df['maj'] < 5) & (df['maj'] > 1.6) & (df['min'] < 5) & (df['min'] > 1.6) & (df['apfit'] > -1)
            & (df['apfit'] < -0.1) & (df['mag5sig'] > 17) & (df['Sky'] > 17) & (df['m'] > 0) & (df['dm'] < 2)]
full = df[(df['duJy'] < 10000) & (df['err'] == 0) & (df['x'] > 100) & (df['x'] < 10460) & (df['y'] > 100)
            & (df['y'] < 10460) & (df['maj'] < 5) & (df['maj'] > 1.6) & (df['min'] < 5) & (df['min'] > 1.6) & (df['apfit'] > -1)
            & (df['apfit'] < -0.1) & (df['mag5sig'] > 17) & (df['Sky'] > 17) & (df['m'] > 0) & (df['dm'] < 2)]

# %%
fig = px.scatter(full, x='MJD', y='m', color='F', error_y='dm',color_discrete_map={
        "c": "cyan",
        "o": "orange",
    })
fig.update_yaxes(autorange="reversed")
fig.show()
