# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
atlas_forced_phot = pd.read_csv(
    "Atlas_difference_lightcurve.txt",
    delim_whitespace=True,   # handles spaces/tabs between columns
    comment="#",             # skips the header line starting with ###
    names=[
        "MJD", "m", "dm", "uJy", "duJy", "F", "err", "chi/N",
        "RA", "Dec", "x", "y", "maj", "min", "phi",
        "apfit", "mag5sig", "Sky", "Obs"
    ])
# Out:
# /tmp/ipykernel_276102/1474568430.py:1: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   atlas_forced_phot = pd.read_csv(

# %%
plt.plot(atlas_forced_phot['MJD'], atlas_forced_phot['duJy'], '-')
plt.show()
# plt.gca().invert_yaxis()
